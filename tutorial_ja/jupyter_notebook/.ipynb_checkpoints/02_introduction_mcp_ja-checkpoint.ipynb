# %% [markdown]
# <p> <center> <a href="../start_here_ja.ipynb">Home Page</a> </center> </p>
#
# <div>
#     <span style="float: left; width: 33%; text-align: left;"><a href="01_inference_endpoint_ja.ipynb">Previous Notebook</a></span>
#     <span style="float: left; width: 34%; text-align: center;">
#         <a href="01_inference_endpoint_ja.ipynb">1</a>
#         <a >2</a>
#         <a href="03_low_level_mcp_ja.ipynb">3</a>
#         <a href="04_langraph_agent_ja.ipynb">4</a>
#         <a href="05_nemo_agent_toolkit_ja.ipynb">5</a>
#         <a href="06_challenge_ja.ipynb">6</a>
#         <a href="bonus_challenge/07_bonus_challenge_ja.ipynb">7</a>
#     </span>
#     <span style="float: left; width: 33%; text-align: right;"><a href="03_low_level_mcp_ja.ipynb">Next Notebook</a></span>
# </div>

# %% [markdown]
# ## 学習目標
# このノートブックを終えると、参加者は以下ができるようになります：
# * Model Context Protocol (MCP) が AI アシスタントを外部ツールやデータソースに接続するためのオープン標準であることを理解する
# * FastMCP の high-level SDK を使って、カスタムのツール定義を持つ MCP server を構築する
# * 2つのアプローチで MCP server をデプロイ・接続する：
#   - **Claude Desktop Integration**: Stdio transport で MCP server を設定する
#   - **Programmatic Access**: HTTP server を起動し、Python MCP client 経由で接続する
# * ツールをプログラム的に探索・呼び出すための MCP client を作成する
# * サーバープロセスを管理する（起動・監視・終了）
# * サードパーティの MCP server を統合する際のセキュリティ上の考慮事項を理解する

# %% [markdown]
# ## Model Context Protocol (MCP) の概要

# %% [markdown]
# **主要コンポーネント：**
# - **MCP Server**: クライアントが呼び出せるツール（関数）を公開する
# - **MCP Client**: MCP server からツールを探索・呼び出す
# - **Transport**: 通信レイヤー（Stdio または HTTP）

# %% [markdown]
# ## MCP Server の作成

# %% [markdown]
# まず、数学ツール（add、subtract）を公開するシンプルな MCP server を作成しましょう。

# %%
# %%writefile mcp_server.py
"""
MCP Server using FastMCP (High-Level SDK)
This server exposes simple math tools that can be invoked by MCP clients.
"""

from mcp.server.fastmcp import FastMCP

# Create an MCP server instance with a descriptive name
mcp = FastMCP("simple-math")

# Define the 'add' tool using the @mcp.tool() decorator
@mcp.tool()
def add(a: int, b: int) -> int:
    """Add two numbers together.
    
    Args:
        a: First integer
        b: Second integer
    
    Returns:
        Sum of a and b
    """
    return a + b

# Define the 'subtract' tool
@mcp.tool()
def subtract(a: int, b: int) -> int:
    """Subtract second number from first.
    
    Args:
        a: First integer
        b: Second integer
    
    Returns:
        Difference (a - b)
    """
    return a - b

if __name__ == "__main__":
    # Run the MCP server with SSE transport over HTTP
    mcp.run(transport="stdio")

# %% [markdown]
# ## ローカルマシンでの MCP Server 起動

# %% [markdown]
# このセクションでは、MCP server を**バックグラウンド subprocess** として起動し、Python client を使ってプログラム的にツールを接続・呼び出せるようにします。

# %% [markdown]
# `subprocess.Popen()` を使ってサーバーをバックグラウンドプロセスとして起動します。これにより：
# - 他のセルを実行している間もサーバーを動かし続けられる
# - 後でクリーンアップするためのプロセス ID（PID）を記録できる

# %%
import subprocess
import time

# Start the HTTP server in the background
server_process = subprocess.Popen(
    ["python", "mcp_server.py"],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE
)

# Wait for server to start
time.sleep(3)

# Store and display the process ID
SERVER_PID = server_process.pid
print(f"Process ID: {SERVER_PID}")

# %% [markdown]
# ### Dual Transport Support を持つ MCP Client クラス

# %% [markdown]
# MCP server に接続する `MCPClient` クラスについて理解しましょう。server 実装と異なり、接続・ツール探索・呼び出しを処理する必要があります：
#
# 1. **`__init__()` の初期化** – セッションのプレースホルダーとリソース管理用の `AsyncExitStack` を設定する
# 2. **`connect_to_server()` の定義** – Stdio transport 経由でローカルサーバーを起動・接続する
# 3. **`connect_to_server_http()` の定義** – HTTP transport 経由でリモートサーバーに接続する
# 4. **`list_tools()` の定義** – 接続した server から利用可能なツールを探索する
# 5. **`call_tool()` の定義** – 引数を渡して特定のツールを実行する
# 6. **`cleanup()` の定義** – `AsyncExitStack` を閉じてすべてのリソースを解放する

# %%
# %%writefile mcp_client.py
"""
MCP Client that connects to and invokes tools from MCP servers.

Supports:
- Stdio transport (for local servers)
- HTTP transport (for remote/HTTP servers)

Usage:
    python mcp_client.py                           # Default: mcp_server.py (stdio)
    python mcp_client.py mcp_server.py             # High-level server (stdio)
    python mcp_client.py mcp_server_low_level.py   # Low-level server (stdio)
    python mcp_client.py --http                    # HTTP mode (localhost:${MCP_PORT:-8000})
    python mcp_client.py --http http://custom:8080/mcp  # Custom HTTP URL
"""

import asyncio
import argparse
import os
from typing import Optional
from contextlib import AsyncExitStack
from mcp import ClientSession, StdioServerParameters
from mcp.client.stdio import stdio_client
from mcp.client.streamable_http import streamablehttp_client

DEFAULT_MCP_PORT = os.environ.get("MCP_PORT") or "8000"
DEFAULT_HTTP_URL = f"http://localhost:{DEFAULT_MCP_PORT}/mcp"


class MCPClient:
    """A client for connecting to MCP servers via Stdio or HTTP transport."""
    
    # ===========================================
    # Step 1: Initialize __init__()
    # Set up session placeholder and AsyncExitStack for resource management
    # ===========================================
    def __init__(self):
        self.session: Optional[ClientSession] = None
        self.exit_stack = AsyncExitStack()
    
    # ===========================================
    # Step 2: Define connect_to_server()
    # Launch and connect to local server via Stdio transport
    # ===========================================
    async def connect_to_server(self, server_script_path: str):
        print(f"→ Connecting to server: {server_script_path}")
        server_params = StdioServerParameters(
            command="python",
            args=[server_script_path]
        )
        stdio_transport = await self.exit_stack.enter_async_context(
            stdio_client(server_params)
        )
        self.stdio, self.write = stdio_transport
        self.session = await self.exit_stack.enter_async_context(
            ClientSession(self.stdio, self.write)
        )
        await self.session.initialize()
    
    # ===========================================
    # Step 3: Define connect_to_server_http()
    # Connect to remote server via HTTP transport
    # ===========================================
    async def connect_to_server_http(self, url: str):
        print(f"→ Connecting to HTTP server: {url}")
        streamablehttp_transport = await self.exit_stack.enter_async_context(
            streamablehttp_client(url)
        )
        self.read, self.write, _ = streamablehttp_transport
        self.session = await self.exit_stack.enter_async_context(
            ClientSession(self.read, self.write)
        )
        await self.session.initialize()
    
    # ===========================================
    # Step 4: Define list_tools()
    # Discover available tools from the connected server
    # ===========================================
    async def list_tools(self):
        res_tools = await self.session.list_tools()
        return res_tools.tools
    
    # ===========================================
    # Step 5: Define call_tool()
    # Execute a specific tool with arguments
    # ===========================================
    async def call_tool(self, tool_name: str, arguments: dict):
        result = await self.session.call_tool(tool_name, arguments)
        return result.content[0].text
    
    # ===========================================
    # Step 6: Define cleanup()
    # Release all resources by closing the AsyncExitStack
    # ===========================================
    async def cleanup(self):
        await self.exit_stack.aclose()


async def test_tools(client: MCPClient):
    """Test the available tools on the connected server."""
    tools = await client.list_tools()
    print(f"\n✓ Connected to server with tools: {[tool.name for tool in tools]}")
    
    print("\n→ Calling add(2, 3)")
    result = await client.call_tool('add', {'a': 2, 'b': 3})
    print(f"  Result: {result}")
    
    print("\n→ Calling subtract(7, 4)")
    result = await client.call_tool('subtract', {'a': 7, 'b': 4})
    print(f"  Result: {result}")


async def main_stdio(server_path: str):
    """Run client with Stdio transport."""
    client = MCPClient()
    try:
        await client.connect_to_server(server_path)
        await test_tools(client)
    finally:
        await client.cleanup()


async def main_http(url: str):
    """Run client with HTTP transport."""
    client = MCPClient()
    try:
        await client.connect_to_server_http(url)
        await test_tools(client)
    finally:
        await client.cleanup()


if __name__ == '__main__':
    parser = argparse.ArgumentParser(
        description="MCP Client - Connect to MCP servers and invoke tools"
    )
    parser.add_argument(
        'server',
        nargs='?',
        default='mcp_server.py',
        help='Path to server script (default: mcp_server.py)'
    )
    parser.add_argument(
        '--http',
        nargs='?',
        const=DEFAULT_HTTP_URL,
        help=f'Use HTTP transport (default URL: {DEFAULT_HTTP_URL})'
    )
    
    args = parser.parse_args()
    
    if args.http:
        url = args.http
        asyncio.run(main_http(url))
    else:
        asyncio.run(main_stdio(args.server))

# %% [markdown]
# クライアントを実行してツールを接続・呼び出してみましょう。

# %%
# !python mcp_client.py

# %% [markdown]
# 完了したら必ずバックグラウンドプロセスをクリーンアップしてください。先ほど保存した PID を使ってサーバーを終了します。

# %%
# !kill -9 {SERVER_PID}
print(f"✓ Server (PID: {SERVER_PID}) killed")

# %% [markdown]
# ### 発展課題
#
# 追加の演算で MCP server を拡張してみましょう：
#
# - `multiply(a, b)` ツールを追加する
# - `divide(a, b)` ツールを追加する（ヒント：ゼロ除算を処理すること！）
# - `mcp.run(transport='streamable-http')` を使って HTTP transport に切り替え、`mcp_client.py` で接続する

# %% [markdown]
# ### 参考リンク

# %% [markdown]
# - [Model Context Protocol](https://modelcontextprotocol.io/docs/getting-started/intro)
# - [Claude](https://claude.com/product/overview)
# - [FastMCP](https://github.com/jlowin/fastmcp)

# %% [markdown]
# ---
#
# ## ライセンス

# %% [markdown]
# Copyright © 2026 OpenACC-Standard.org. 本資料は OpenACC-Standard.org が NVIDIA Corporation との協力のもと、Creative Commons Attribution 4.0 International (CC BY 4.0) ライセンスのもとで公開しています。本資料には他の団体が開発したハードウェアおよびソフトウェアへの参照が含まれており、該当するすべてのライセンスおよび著作権が適用されます。

# %% [markdown]
# <p> <center> <a href="../start_here_ja.ipynb">Home Page</a> </center> </p>
#
# <div>
#     <span style="float: left; width: 33%; text-align: left;"><a href="01_inference_endpoint_ja.ipynb">Previous Notebook</a></span>
#     <span style="float: left; width: 34%; text-align: center;">
#         <a href="01_inference_endpoint_ja.ipynb">1</a>
#         <a >2</a>
#         <a href="03_low_level_mcp_ja.ipynb">3</a>
#         <a href="04_langraph_agent_ja.ipynb">4</a>
#         <a href="05_nemo_agent_toolkit_ja.ipynb">5</a>
#         <a href="06_challenge_ja.ipynb">6</a>
#         <a href="bonus_challenge/07_bonus_challenge_ja.ipynb">7</a>
#     </span>
#     <span style="float: left; width: 33%; text-align: right;"><a href="03_low_level_mcp_ja.ipynb">Next Notebook</a></span>
# </div>
